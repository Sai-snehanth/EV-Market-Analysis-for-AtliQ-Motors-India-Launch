# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fullset = pd.read_csv(r"C:\Users\saisn\Downloads\RPC12_Input_For_Participants\RPC12_Input_For_Participants\datasets\fulldatset.csv")

# %%
fullset
# Out:
#                      date vehicle_category         maker  \
# 0     2021-04-01 00:00:00     two wheelers  OLA ELECTRIC
# 1     2022-04-01 00:00:00     two wheelers      OKAYA EV
# 2     2021-05-01 00:00:00     two wheelers  OLA ELECTRIC
# 3     2021-06-01 00:00:00     two wheelers  OLA ELECTRIC
# 4     2021-07-01 00:00:00     two wheelers  OLA ELECTRIC
# ...                   ...              ...           ...
# 3256  2024-03-01 00:00:00      twoWheelers           NaN
# 3257  2024-03-01 00:00:00      twoWheelers           NaN
# 3258  2024-03-01 00:00:00      twoWheelers           NaN
# 3259  2024-03-01 00:00:00      twoWheelers           NaN
# 3260  2024-03-01 00:00:00      twoWheelers           NaN
#
#       electric_vehicles_sold  total_vehicles_sold
# 0                          0                  NaN
# 1                          0                  NaN
# 2                          0                  NaN
# 3                          0                  NaN
# ...

# %%
fullset.head()
# Out:
#                   date vehicle_category         maker  electric_vehicles_sold  \
# 0  2021-04-01 00:00:00     two wheelers  OLA ELECTRIC                       0
# 1  2022-04-01 00:00:00     two wheelers      OKAYA EV                       0
# 2  2021-05-01 00:00:00     two wheelers  OLA ELECTRIC                       0
# 3  2021-06-01 00:00:00     two wheelers  OLA ELECTRIC                       0
# 4  2021-07-01 00:00:00     two wheelers  OLA ELECTRIC                       0
#
#    total_vehicles_sold
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
fullset.tail()
# Out:
#                      date vehicle_category maker  electric_vehicles_sold  \
# 3256  2024-03-01 00:00:00      twoWheelers   NaN                      58
# 3257  2024-03-01 00:00:00      twoWheelers   NaN                      25
# 3258  2024-03-01 00:00:00      twoWheelers   NaN                      13
# 3259  2024-03-01 00:00:00      twoWheelers   NaN                       2
# 3260  2024-03-01 00:00:00      twoWheelers   NaN                       2
#
#       total_vehicles_sold
# 3256               1932.0
# 3257                780.0
# 3258               1394.0
# 3259                447.0
# 3260               1180.0

# %%
fullset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3261 entries, 0 to 3260
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    3261 non-null   object
#  1   vehicle_category        3261 non-null   object
#  2   maker                   816 non-null    object
#  3   electric_vehicles_sold  3261 non-null   int64
#  4   total_vehicles_sold     2445 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 127.5+ KB

# %%
fullset.isnull()
# Out:
#        date  vehicle_category  maker  electric_vehicles_sold  \
# 0     False             False  False                   False
# 1     False             False  False                   False
# 2     False             False  False                   False
# 3     False             False  False                   False
# 4     False             False  False                   False
# ...     ...               ...    ...                     ...
# 3256  False             False   True                   False
# 3257  False             False   True                   False
# 3258  False             False   True                   False
# 3259  False             False   True                   False
# 3260  False             False   True                   False
#
#       total_vehicles_sold
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# ...                   ...
# 3256                False
# ...

# %%
fullset.describe()
# Out:
#        electric_vehicles_sold  total_vehicles_sold
# count             3261.000000          2445.000000
# mean              1267.164060         23402.966053
# std               3131.235478         38353.266389
# min                  0.000000             1.000000
# 25%                  4.000000          1158.000000
# 50%                101.000000          6098.000000
# 75%                871.000000         29396.000000
# max              44630.000000        387983.000000

# %%
fullset.describe().T
# Out:
#                          count          mean           std  min     25%  \
# electric_vehicles_sold  3261.0   1267.164060   3131.235478  0.0     4.0
# total_vehicles_sold     2445.0  23402.966053  38353.266389  1.0  1158.0
#
#                            50%      75%       max
# electric_vehicles_sold   101.0    871.0   44630.0
# total_vehicles_sold     6098.0  29396.0  387983.0

# %%
fullset.columns
# Out:
# Index(['date', 'vehicle_category', 'maker', 'electric_vehicles_sold',
#        'total_vehicles_sold'],
#       dtype='object')

# %%
sns.heatmap(fullset.describe(),annot=True,linewidth=0.5)
# Out:
# <Axes: >
