# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\saisn\Downloads\RPC12_Input_For_Participants\RPC12_Input_For_Participants\datasets\electric_vehicle_sales_by_makers.csv")

# %%
print(dataset)
# Out:
#            date vehicle_category            maker  electric_vehicles_sold
# 0    2021-04-01     two wheelers     OLA ELECTRIC                       0
# 1    2022-04-01     two wheelers         OKAYA EV                       0
# 2    2021-05-01     two wheelers     OLA ELECTRIC                       0
# 3    2021-06-01     two wheelers     OLA ELECTRIC                       0
# 4    2021-07-01     two wheelers     OLA ELECTRIC                       0
# ..          ...              ...              ...                     ...
# 811  2024-03-01     two wheelers           BGAUSS                    3070
# 812  2024-03-01     two wheelers  BATTRE ELECTRIC                     625
# 813  2024-03-01     two wheelers    KINETIC GREEN                    3915
# 814  2024-03-01     two wheelers           REVOLT                     585
# 815  2024-03-01     two wheelers           OTHERS                   10579
#
# [816 rows x 4 columns]

# %%
dataset.head()
# Out:
#          date vehicle_category         maker  electric_vehicles_sold
# 0  2021-04-01     two wheelers  OLA ELECTRIC                       0
# 1  2022-04-01     two wheelers      OKAYA EV                       0
# 2  2021-05-01     two wheelers  OLA ELECTRIC                       0
# 3  2021-06-01     two wheelers  OLA ELECTRIC                       0
# 4  2021-07-01     two wheelers  OLA ELECTRIC                       0

# %%
dataset.tail()
# Out:
#            date vehicle_category            maker  electric_vehicles_sold
# 811  2024-03-01     two wheelers           BGAUSS                    3070
# 812  2024-03-01     two wheelers  BATTRE ELECTRIC                     625
# 813  2024-03-01     two wheelers    KINETIC GREEN                    3915
# 814  2024-03-01     two wheelers           REVOLT                     585
# 815  2024-03-01     two wheelers           OTHERS                   10579

# %%
dataset.describe()
# Out:
#        electric_vehicles_sold
# count              816.000000
# mean              2531.998775
# std               4771.077333
# min                  0.000000
# 25%                 42.000000
# 50%                662.000000
# 75%               2636.500000
# max              44630.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    816 non-null    object
#  1   vehicle_category        816 non-null    object
#  2   maker                   816 non-null    object
#  3   electric_vehicles_sold  816 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 25.6+ KB

# %%
dataset.isnull()
# Out:
#       date  vehicle_category  maker  electric_vehicles_sold
# 0    False             False  False                   False
# 1    False             False  False                   False
# 2    False             False  False                   False
# 3    False             False  False                   False
# 4    False             False  False                   False
# ..     ...               ...    ...                     ...
# 811  False             False  False                   False
# 812  False             False  False                   False
# 813  False             False  False                   False
# 814  False             False  False                   False
# 815  False             False  False                   False
#
# [816 rows x 4 columns]

# %%
dataset.describe().T
# Out:
#                         count         mean          std  min   25%    50%  \
# electric_vehicles_sold  816.0  2531.998775  4771.077333  0.0  42.0  662.0
#
#                            75%      max
# electric_vehicles_sold  2636.5  44630.0

# %%
dataset.columns
# Out:
# Index(['date', 'vehicle_category', 'maker', 'electric_vehicles_sold'], dtype='object')

# %%
plt.plot(dataset['date'],dataset['electric_vehicles_sold'])
plt.show()
plt.figure(figsize=(20, 10))

# %%
plt.bar(dataset['date'],dataset['electric_vehicles_sold'])
# Out:
# <BarContainer object of 816 artists>

# %%
sns.heatmap(dataset.describe(),annot=True,linewidth=0.5)
# Out:
# <Axes: >
