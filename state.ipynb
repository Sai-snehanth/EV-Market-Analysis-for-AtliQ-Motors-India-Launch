# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\saisn\Downloads\RPC12_Input_For_Participants\RPC12_Input_For_Participants\datasets\electric_vehicle_sales_by_state.csv")

# %%
data
# Out:
#             date                       state vehicle_category  \
# 0     2021-04-01                      Sikkim      twoWheelers
# 1     2021-04-01                      Sikkim     fourWheelers
# 2     2021-05-01                      Sikkim      twoWheelers
# 3     2021-05-01                      Sikkim     fourWheelers
# 4     2021-06-01                      Sikkim      twoWheelers
# ...          ...                         ...              ...
# 2440  2024-03-01                     Mizoram      twoWheelers
# 2441  2024-03-01                  DNH and DD      twoWheelers
# 2442  2024-03-01                     Manipur      twoWheelers
# 2443  2024-03-01  Andaman and Nicobar Island      twoWheelers
# 2444  2024-03-01                    Nagaland      twoWheelers
#
#       electric_vehicles_sold  total_vehicles_sold
# 0                          0                  398
# 1                          0                  361
# 2                          0                  113
# ...

# %%
data.head()
# Out:
#          date   state vehicle_category  electric_vehicles_sold  \
# 0  2021-04-01  Sikkim      twoWheelers                       0
# 1  2021-04-01  Sikkim     fourWheelers                       0
# 2  2021-05-01  Sikkim      twoWheelers                       0
# 3  2021-05-01  Sikkim     fourWheelers                       0
# 4  2021-06-01  Sikkim      twoWheelers                       0
#
#    total_vehicles_sold
# 0                  398
# 1                  361
# 2                  113
# 3                   98
# 4                  229

# %%
data.tail()
# Out:
#             date                       state vehicle_category  \
# 2440  2024-03-01                     Mizoram      twoWheelers
# 2441  2024-03-01                  DNH and DD      twoWheelers
# 2442  2024-03-01                     Manipur      twoWheelers
# 2443  2024-03-01  Andaman and Nicobar Island      twoWheelers
# 2444  2024-03-01                    Nagaland      twoWheelers
#
#       electric_vehicles_sold  total_vehicles_sold
# 2440                      58                 1932
# 2441                      25                  780
# 2442                      13                 1394
# 2443                       2                  447
# 2444                       2                 1180

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2445 entries, 0 to 2444
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    2445 non-null   object
#  1   state                   2445 non-null   object
#  2   vehicle_category        2445 non-null   object
#  3   electric_vehicles_sold  2445 non-null   int64
#  4   total_vehicles_sold     2445 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 95.6+ KB

# %%
data.isnull()
# Out:
#        date  state  vehicle_category  electric_vehicles_sold  \
# 0     False  False             False                   False
# 1     False  False             False                   False
# 2     False  False             False                   False
# 3     False  False             False                   False
# 4     False  False             False                   False
# ...     ...    ...               ...                     ...
# 2440  False  False             False                   False
# 2441  False  False             False                   False
# 2442  False  False             False                   False
# 2443  False  False             False                   False
# 2444  False  False             False                   False
#
#       total_vehicles_sold
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 2440                False
# ...

# %%
data.describe()
# Out:
#        electric_vehicles_sold  total_vehicles_sold
# count             2445.000000          2445.000000
# mean               845.035174         23402.966053
# std               2185.167744         38353.266389
# min                  0.000000             1.000000
# 25%                  2.000000          1158.000000
# 50%                 54.000000          6098.000000
# 75%                534.000000         29396.000000
# max              26668.000000        387983.000000

# %%
data.describe().T
# Out:
#                          count          mean           std  min     25%  \
# electric_vehicles_sold  2445.0    845.035174   2185.167744  0.0     2.0
# total_vehicles_sold     2445.0  23402.966053  38353.266389  1.0  1158.0
#
#                            50%      75%       max
# electric_vehicles_sold    54.0    534.0   26668.0
# total_vehicles_sold     6098.0  29396.0  387983.0

# %%
data.columns
# Out:
# Index(['date', 'state', 'vehicle_category', 'electric_vehicles_sold',
#        'total_vehicles_sold'],
#       dtype='object')

# %%
sns.heatmap(data.describe(),annot=True,linewidth=0.5)
# Out:
# <Axes: >

# %%
plt.plot(data['state'],data['electric_vehicles_sold'])

# %%
plt.plot(data['state'],data['total_vehicles_sold'])

# %%
plt.bar(data['state'],data['total_vehicles_sold'])
# Out:
# <BarContainer object of 2445 artists>

# %%
plt.bar(data['state'],data['electric_vehicles_sold'])
# Out:
# <BarContainer object of 2445 artists>
